# %%
import os
import openai
import pandas as pd
from IPython.display import display, Markdown
import questionary

# %%
openai.api_key = os.environ['SYS_OPENIA_API_KEY']

# %%
class IPER_Row:
    '''
    Fila de la Matriz IPER.
    En términos simples, IPER es una descripción organizada de las actividades, 
    controles y peligros que permitan identificar los posibles riesgos. 
    Esta permitirá evaluar, monitorear, controlar y comunicar estos peligros 
    o sucesos no deseados, pudiendo también identificar los niveles de riesgo 
    y las consecuencias de estos.

    Los valores y definiciones de los distintos indicadores se describen a continuación:
        Índice de número de personas expuestas (self.INPE): Se determina en función de la cantidad de personas expuestas, en el lugar o entorno de trabajo.
        0: No aplica (NO existe exposición de personas, sólo de equipos/infraestructura)
        1: De 1 a 10 personas      
        2: De 11 a 20 personas
        3: Más de 20 personas

        Índice de Frecuencia y Duración de la exposición (self.IFDE): Considera dos variables, “Frecuencia” y “Duración” de la exposición según la siguiente tabla:
        Frecuencia de exposición del personal Duración de la exposición Índice 
        4: DIARIA o todos los días Menos del 50% del turno de trabajo
        5: DIARIA o todos los días Más del 50% del turno de trabajo
        3: SEMANALMENTE o todas las semanas (pero no se reitera cada día) Menos del 50% del turno de trabajo
        4: SEMANALMENTE o todas las semanas (pero no se reitera cada día) Más del 50% del turno de trabajo
        2: MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE Menos del 50% del turno de trabajo 
        3: MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE Más del 50% del turno de trabajo
        1: Se realiza con una frecuencia mayor a la SEMESTRAL Menos del 50% del turno de trabajo
        2: Se realiza con una frecuencia mayor a la SEMESTRAL Más del 50% del turno de trabajo
        2: Se está evaluando en Condiciones de Falla/no rutinaria o Anormales ó sólo se exponen equipos, no personas 

        Índice de Controles existentes (self.ICO)
        1: Existen controles implementados → Se tienen al menos tres condiciones implementadas (A, B, C ó D) 
        6: Existen controles parciales → Se tienen dos condiciones implementadas
        10: Los controles son bajos o insuficientes o no están implementados → 
        * Se cumple sólo una condición implementada o ninguna ó 
        * se identificaron "permanentes" desvíos comportamentales de incumplimiento a las normas referidas al peligro ó 
        * Es una evaluación "IPER anticipada para actividades" 

            Condiciones 
            Condicion A.  Existen ya implementados como parte del SGI procedimientos/documentos o controles operativos específself.ICOs para controlar el Peligro (p.e. PT, EPP, bloqueo/etiquetado, IT, guías, normas, inspecciones específicas).
            Condicion B.  Para el peligro específself.ICO existen implementados medios de infraestructura o ingeniería o protección colectiva o de emergencia para el Peligro (resguardos, barandas, cubiertas, líneas de vida, barreras de protección, aislamientos, medios de detección/alarma del peligro, dispositivos de enclavamiento/corte automátself.ICO, extintores, accesorios para mejorar la ergonomía, mantenimiento preventivo).
            Condicion C.  El personal ya tiene experiencia o fue capacitado/entrenado sobre el peligro específself.ICO al realizar la actividad.
            Condicion D. Se cuenta con señalización/alerta específica in-situ implementada para el peligro o situación peligrosa.

        Criterios de Severidad de Daño:
        1: "Daño Menor"
            - Lesiones que sólo requieren primeros auxilios o atención médica de seguimiento.
            - Lesiones/enfermedades que ocasionan ausencia laboral de menos de un día o transferencia de actividad por ese período.
            - Daños a equipos con costos estimados menores a 1,000 USD.

        2: "Daño Mediano"
            - Lesiones/enfermedades que ocasionan ausencia laboral temporal de 1 día a 1 mes o transferencia de actividad por ese período.
            - Daños a equipos con costos entre 1,001 y 10,000 USD.

        3: "Daño Mayor"
            - Lesiones que ocasionan ausencia laboral temporal de 1 mes a 6 meses o transferencia de actividad por ese período.
            - Lesiones/enfermedades que ocasionan "incapacidades permanentes parciales".
            - Daños a equipos con costos entre 10,001 y 100,000 USD.

        4: "Daño Extremo"
            - Lesiones/enfermedades que ocasionan ausencia laboral temporal de 6 meses a 1 año o transferencia de actividad por ese período.
            - Lesiones o enfermedades que generan "incapacidad total" al trabajador.
            - Muerte.
            - Daños a equipos con costos estimados superiores a 100,000 USD.
    '''
    def __init__(self, sector, subsector, person_count, usage_time, implemented_controls,  problem_description):
        
        self.sector = sector # string
        self.subsector = subsector # string
        self.problem_description = problem_description # string
        self.implemented_controls = implemented_controls # list
        self.person_count = person_count #int
        self.usage_time = usage_time #int horas-semana

        # Indices
        self.INPE = self._get_inpe()
        self.IFDE = self._get_ifde() 
        self.ICO = self._get_ico()

        self.probabilidad = self._evaluar_probabilidad()
        self.nivel_de_riesgo = self._calcular_nivel_riesgo()
        self.aceptabilidad = self._evaluar_aceptabilidad()

        self.severidad_daño = self._get_severidad()
        self.string_severidad_daño = _get_severidad_daño()

        self.condicion_evaluacion = self._elegir_condicion()
        self.peligro = self._seleccionar_peligro()
        self.origen_peligro = self._generar_origen_peligrp()
        self.controles_pre_existentes = self._generar_controles_pre_existentes() 

        self.opciones_peligro = {
            1: "A1. Caída de personas al mismo nivel",
            2: "A2. Caídas menores a distinto nivel (entre 0,3 y 1,8 m)",
            3: "A3. Caídas mayores a distinto nivel (mayor a 1,8 m)",
            4: "A4. Contactos eléctricos (Choque eléctrico)",
            5: "A5. Contactos con partes o elementos calientes/fríos",
            6: "A6. Proyección de partículas, fragmentos",
            7: "A7. Proyección de gases, polvo o líquidos a presión ó calientes",
            8: "A8. Atrapamientos mecánicos",
            9: "A9. Cortes, golpes, penetraciones por herramientas",
            10: "A10. Cortes, golpes, penetraciones, excoriaciones de otra clase (no por herramientas)",
            11: "A11. Caída de objetos menores (menos de 5 kg) o herramientas",
            12: "A12. Aplastamiento/Ahogamiento (entre objetos o por caída/deslizamiento de objetos mayores a 5 Kg)",
            13: "A13. Golpes por objetos/equipos móviles o atropellamiento por vehículos",
            14: "A14. Golpes por objetos inmóviles o partes salientes",
            15: "A15. Incendios",
            16: "A16. Explosiones / deflagraciones",
            17: "A17. Choques de vehículos en movimiento",
            18: "A18. Vuelcos vehiculares o de equipo",
            19: "A19. Exposición a ruido",
            20: "A20. Exposición a vibraciones",
            21: "A21. Exposición a inadecuada iluminación",
            22: "A22. Exposición a temperaturas extremas (extremadamente mayor a la normal o menor a 0°C)",
            23: "A23. Exposición a humedad extrema",
            24: "A24. Exposición a radiaciones ionizantes",
            25: "A25. Exposición a radiaciones no ionizantes",
            26: "B1. Contacto o ingestión de sólidos/líquidos peligrosos",
            27: "B2. Exposición a polvos o fibras",
            28: "B3. Exposición a gases/vapores tóxicos o asfixiantes",
            29: "B4. Derrames o fugas mayores de sustancias peligrosas",
            30: "B5. Exposición a insectos/animales peligrosos",
            31: "B6. Exposición a bacterias, virus u hongos",
            32: "C1. Ejecución de posturas inadecuadas",
            33: "C2. Ejecución de movimientos repetitivos",
            34: "C3. Ejecución de sobre esfuerzo físicos",
            35: "C4. Exposición a sobre esfuerzo visual",
            36: "C5. Exposición a sobre esfuerzo mental",
            37: "D1. Sismos",
            38: "D2. Inundaciones (por lluvias o granizadas intensas o desborde de ríos)",
            39: "D3. Tormentas eléctricas o de vientos huracanados",
            40: "D4. Deslizamientos de tierra",
            41: "D5. Incendios de plantas aledañas o forestales",
            42: "D6. Convulsión social"
        }

    def _evaluar_probabilidad(self):
        '''
        Evalúa la probabilidad de riesgo en función de los indicadores.

        Args:
            self.INPE (int): Índice de número de personas expuestas. (0-3)
            self.IFDE (int): Índice de Frecuencia y Duración de la exposición. (1-5)
            self.ICO (int): Índice de Controles existentes. (1, 6, 10)

        Returns:
            int: Valor de la probabilidad de riesgo (1-5) o None si no se cumple ninguna condición.
        '''
        suma = self.INPE + self.IFDE + self.ICO
        if suma <= 6:
            return 1
        elif suma <= 10:
            return 2
        elif suma <= 14:
            return 3
        elif suma <= 18:
            return 4
        elif suma > 18:
            return 5
        else:
            return None

    def _calcular_nivel_riesgo(self):
        '''
        Calcula el nivel de riesgo en función de la probabilidad y la severidad del daño.

        Args:
            self.probabilidad (int): Valor de la probabilidad de riesgo (1-5).
            self.severidad_daño (int): Valor de la severidad del daño (1-5).

        Returns:
            str: Nivel de riesgo ("Trivial", "Bajo", "Moderado", "Alto" o "Intolerable").
        '''
        resultado = self.probabilidad * self.severidad_daño
        nivel = ""
        if resultado <= 2:
            nivel = "Trivial"
        elif resultado <= 6:
            nivel = "Bajo"
        elif resultado <= 9:
            nivel = "Moderado"
        elif resultado <= 15:
            nivel = "Alto"
        elif resultado >= 16:
            nivel = "Intolerable"

        return nivel

    def _evaluar_aceptabilidad(self):
        '''
        Evalúa la aceptabilidad del riesgo en función de la probabilidad y la severidad del daño.

        Args:
            self.probabilidad (int): Valor de la probabilidad de riesgo (1-5).
            self.severidad_daño (int): Valor de la severidad del daño (1-5).

        Returns:
            str: Aceptabilidad del riesgo ("Aceptable" o "No Aceptable").
        '''
        resultado = self.probabilidad * self.severidad_daño
        nivel = ""
        if resultado > 7:
            nivel = "No Aceptable"
        else:
            nivel = "Aceptable"

        return nivel

    def _elegir_condicion(self):

        # Define the prompt using self.problem_description
        prompt = f"""Selecciona la condición más adecuada basada en la siguiente descripción:

        Descripción del problema: 
        {self.problem_description}

        Opciones de condición:
        0. Normal/Rutinaria
        1. Anormal/Emergencia/No rutinaria
        """

        # Generate a response using the ChatGPT API
        response = openai.Completion.create(
            engine='davinci',
            prompt=prompt,
            max_tokens=1,
            n=1,
            stop=None,
            temperature=0,
        )

        # Extract the selected option (con_eval) from the generated response
        con_eval = int(response.choices[0].text.strip())

        if con_eval == 0:
            return "Normal/Rutinaria"
        elif con_eval == 1:
            return "Anormal/Emergencia/No rutinaria"
        else:
            return None

    def _seleccionar_peligro(self):
        # Define the prompt using self.problem_description and opciones_peligro
        prompt = f"""Selecciona el peligro más adecuado basado en la siguiente descripción:

        Descripción del problema: {self.problem_description}

        Opciones de peligro:
        {self.opciones_peligro}
        """

        # Generate a response using the ChatGPT API
        response = openai.Completion.create(
            engine='davinci',
            prompt=prompt,
            max_tokens=1,
            n=1,
            stop=None,
            temperature=0,
        )

        # Extract the selected option (key) from the generated response
        selected_option = int(response.choices[0].text.strip())

        return selected_option

    def _generar_origen_peligro(self):
        pass

    def _generar_controles_pre_existentes(self):
        pass
    
    def _get_severidad(self):
        danio_menor = [1, 2, 5, 9, 10, 14, 19, 20, 21, 22, 23, 25, 29, 30, 31, 32, 33, 34, 35, 36, 39, 40, 41, 42]
        danio_mediano = [3, 4, 7, 8, 13, 17, 18, 24, 27, 37]
        danio_mayor = [6, 11, 16, 26, 38]
        danio_extremo = [15, 25]
        if self.peligro in danio_menor:
            return 1 
        elif self.peligro in danio_mediano:
            return 2 
        elif self.peligro in danio_mayor:
            return 3 
        elif self.peligro in danio_extremo:
            return 4
        else:
            return 0
    
    def _get_inpe(self):
        opciones_cantidad = [
            'No aplica (NO existe exposición de personas, sólo de equipos/infraestructura',
            'De 1 a 10 personas',
            'De 11 a 20 personas',
            'Más de 20 personas'
            ]

        cantidad = select('Selecciona una opción', choices=opciones_cantidad).ask()

        if cantidad == 'De 1 a 10 personas':
            return 1
        elif cantidad == 'De 11 a 20 personas':
            return 3
        elif cantidad == 'Más de 20 personas':
            return 5
        else:
            return None

        
    def _get_ifde(self):
        opciones_frecuencia = [
        'DIARIA o todos los días',
        'SEMANALMENTE o todas las semanas (pero no se reitera cada día)',
        'MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE',
        'Se realiza con una frecuencia mayor a la SEMESTRAL',
        'Se está evaluando en Condiciones de Falla/no rutinaria o Anormales ó sólo se exponen equipos, no personas'
        ]

        opciones_duracion = [
            'Menos del 50% del turno de trabajo',
            'Más del 50% del turno de trabajo'
            ]

        frecuencia = select('Selecciona una opción', choices=opciones_frecuencia).ask()

        if frecuencia == 'DIARIA o todos los días':
            duracion = select('Selecciona una opción', choices=opciones_duracion).ask()
            if duracion == 'Menos del 50% del turno de trabajo':
                return 4
            else:
                return 5
        elif frecuencia == 'SEMANALMENTE o todas las semanas (pero no se reitera cada día)':
            duracion = select('Selecciona una opción', choices=opciones_duracion).ask()
            if duracion == 'Menos del 50% del turno de trabajo':
                return 3
            else:
                return 4
        elif frecuencia == 'MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE':
            duracion = select('Selecciona una opción', choices=opciones_duracion).ask()
            if duracion == 'Menos del 50% del turno de trabajo':
                return 2
            else:
                return 3
        elif frecuencia == 'Se realiza con una frecuencia mayor a la SEMESTRAL':
            duracion = select('Selecciona una opción', choices=opciones_duracion).ask()
            if duracion == 'Menos del 50% del turno de trabajo':
                return 1
            else:
                return 2
        elif frecuencia == 'Se está evaluando en Condiciones de Falla/no rutinaria o Anormales ó sólo se exponen equipos, no personas':
            return 2
        else:
            return None

        def _get_ico(self):
            x = len(self.implemented_controls)
            if x => 3:
                return 1 
            elif x == 2:
                return 6
            elif x == 1:
                return 10
        

# Create an instance of Iper_Row
iper_row = IPER_Row(INPE=2, IFDE=4, ICO=1, severidad_daño=3)
iper_row.probabilidad

# %%
from questionary import select


def obtener_IFDE():
    opciones_frecuencia = [
        'DIARIA o todos los días',
        'SEMANALMENTE o todas las semanas (pero no se reitera cada día)',
        'MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE',
        'Se realiza con una frecuencia mayor a la SEMESTRAL',
        'Se está evaluando en Condiciones de Falla/no rutinaria o Anormales ó sólo se exponen equipos, no personas'
    ]

    opciones_duracion = [
        'Menos del 50% del turno de trabajo',
        'Más del 50% del turno de trabajo',
    ]

    frecuencia = input('Selecciona la frecuencia de exposición del personal: ')
    duracion = input('Selecciona la duración de la exposición: ')

    if frecuencia == 'DIARIA o todos los días':
        if duracion == 'Menos del 50% del turno de trabajo':
            return 4
        else:
            return 5
    elif frecuencia == 'SEMANALMENTE o todas las semanas (pero no se reitera cada día)':
        if duracion == 'Menos del 50% del turno de trabajo':
            return 3
        else:
            return 4
    elif frecuencia == 'MENSUALMENTE (pero no se reitera cada semana) a SEMESTRALMENTE':
        if duracion == 'Menos del 50% del turno de trabajo':
            return 2
        else:
            return 3
    elif frecuencia == 'Se realiza con una frecuencia mayor a la SEMESTRAL':
        if duracion == 'Menos del 50% del turno de trabajo':
            return 1
        else:
            return 2
    elif frecuencia == 'Se está evaluando en Condiciones de Falla/no rutinaria o Anormales ó sólo se exponen equipos, no personas':
        return 0
    else:
        return None


resultado = obtener_IFDE()
if resultado is not None:
    print(f'Índice de Frecuencia y Duración de la exposición (self.IFDE): {resultado}')
else:
    print('Opción inválida')
# Out:
# Opción inválida

# %%
# Configure pandas display options
pd.set_option('display.max_rows', None)     # Print all rows
pd.set_option('display.max_columns', None)  # Print all columns

# Read the Excel file
file_path = 'IPER_example.xlsx'
df = pd.read_excel(file_path)
# Drop rows with NaN values
df = df.dropna()

df.head()
# Out:
#    # SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO  \
# 1  2                                       1er Piso
# 4  5                                       1er Piso
# 5  6                                       1er Piso
# 6  7                                       1er Piso
# 7  8                                       1er Piso
#
#   ACTIVIDAD / TAREA / LUGAR / EQUIPO / EVENTO  \
# 1                     OF SUB GERENCIA TECNICA
# 4                                     PASILLO
# 5                                     PASILLO
# 6                                     PASILLO
# 7                                     PASILLO
#
#            CONDICIÓN DE EVALUACIÓN  \
# 1  Anormal/Emergencia/No rutinaria
# 4                 Normal/Rutinaria
# 5                 Normal/Rutinaria
# 6  Anormal/Emergencia/No rutinaria
# 7  Anormal/Emergencia/No rutinaria
#
#   PELIGRO_x000D_\n_x000D_\n(Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001)  \
# 1                                   A15.   Incendios
# 4          A1.      Caída de personas al mismo nivel
# 5  A2.      Caídas menores a distinto nivel (entr...
# 6   A4.      Contactos eléctricos (Choque eléctrico)
# 7                                   A15.   Incendios
#
#   CONSECUENCIAS_x000D_\nmas probables_x000D_\n_x000D_\n(Lesiones o daños mas probables)  \
# 1  Daños a instalaciones y/o equipos, quemaduras,...
# 4   Traumatismos, heridas, Golpes, contusiones, e...
# 5         Traumatismos, heridas, fracturas múltiples
# 6  Quemaduras internas, externas, arritmia y paro...
# 7  Daños a instalaciones y/o equipos, quemaduras,...
#
#   DESVIO O CAUSA QUE ORIGINA EL PELIGRO_x000D_\n¿Por qué se genera el peligro?_x000D_\n_x000D_\nCausas/Devío: (Condiciones inseguras / Factores inseguros del Trabajo / Deficiencias de seguridad/ Actos Inseguros que generan el peligro)_x000D_\n_x000D_\nElementos: (Energías, equipos, maquinarias, sustancias, etc.)  \
# 1  Incendio por descargas eléctricas, cortos circ...
# 4  Superficie de área de trabajo en mal estado (A...
# 5  Uso contínuo de gradas fijas, deficiente ilumi...
# 6  El tablero eléctrico no tiene seguro (acceso a...
# 7  Incendio por descargas, corto circuitos, Insta...
#
#   DETERMINACIÓN DE LOS CONTROLES O PROTECCIÓNES EXISTENTES_x000D_\n_x000D_\n(Determine aquellos controles preventivos o de protección actualmente existentes)  \
# 1  1. Capacitacion de prevención de incendios con...
# 4                                            NINGUNO
# 5                        1. Monitoreo de iluminancia
# 6                                            NINGUNO
# 7  1. Capacitacion de prevención de incendios con...
#
#   SEVERIDAD_x000D_\n_x000D_\nDEL DAÑO  SEVERIDAD_x000D_\n_x000D_\nDEL DAÑO.1  \
# 1                        Daño Extremo                                      4
# 4                        Daño Mediano                                      2
# 5                          Daño Mayor                                      3
# 6                          Daño Mayor                                      3
# 7                        Daño Extremo                                      4
#
#    INPE  IFDE  ICO   ∑  Prob.  Prob..1 NIVEL DEL RIESGO  \
# 1     1     2   10  13  Media        3             Alto
# 4     1     5   10  16   Alta        4         Moderado
# 5     1     5   10  16   Alta        4             Alto
# 6     1     2   10  13  Media        3         Moderado
# 7     1     2   10  13  Media        3             Alto
#
#   ACEPTABLE / NO ACEPTABLE      ES REQUISITO LEGAL? CUAL  \
# 1             No Aceptable        SI, Ley 16998 Art. 123
# 4             No Aceptable       SI, Ley Nº 16998 Art 58
# 5             No Aceptable                            SI
# 6             No Aceptable  SI\nLey Nº 16998 Art 123-130
# 7             No Aceptable                            SI
#
#   MEDIDAS ADICIONALES DE CONTROL O PROTECCIÓN  PROPUESTAS_x000D_\n_x000D_\n(Debe atacar las CAUSAS identificadas)_x000D_\n_x000D_\n1. Eliminacion: _x000D_\n2. Sustitucion: _x000D_\n3.Controles Ingenieria/Protección colectiva:_x000D_\n4. Señalización/Controles administrativos: _x000D_\n5. EPP:  \
# 1  1. Realizar Mantenimiento preventivo de las in...
# 4  4. Mejorar las condiciones de las alfombras\n4...
# 5  1. Realizar inspecciones de orden, limpieza y ...
# 6  3. Colocar candado o chapa\n3. Realizar manten...
# 7  1. Instalación de Termico\n3. Instalación de e...
#
#   SEVERIDAD RESIDUAL _x000D_\nDEL DAÑO_x000D_\n_x000D_\n(analizar si hay disminución)  \
# 1                                       Daño Extremo
# 4                                       Daño Mediano
# 5                                         Daño Mayor
# 6                                         Daño Mayor
# 7                                       Daño Extremo
#
#    SEVERIDAD RESIDUAL _x000D_\nDEL DAÑO_x000D_\n_x000D_\n(analizar si hay disminución).1  \
# 1                                                4.0
# 4                                                2.0
# 5                                                3.0
# 6                                                3.0
# 7                                                4.0
#
#    INPE.1  IFDE.1  ICO.1   ∑.1   Prob..2  Prob..3 NUEVO NIVEL DEL RIESGO  \
# 1     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 4     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 5     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 6     1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 7     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
#
#   ACEPTABLE / NO ACEPTABLE.1
# 1                  Aceptable
# 4                  Aceptable
# 5                  Aceptable
# 6                  Aceptable
# 7                  Aceptable

# %%
df.sort_values(by=['PELIGRO_x000D_\n_x000D_\n(Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001)'])
# Out:
#        #     SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO  \
# 33    34                                              Patio
# 97    98                                  Almacen Sopocachi
# 40    41                                        Planta Baja
# 23    24                                              Patio
# 45    46                                        Planta Baja
# 128  129                                          Logistica
# 50    51                                        Planta Baja
# 64    65                                        Planta Baja
# 55    56                                        Planta Baja
# 69    70                                        Planta Baja
# 60    61                                        Planta Baja
# 4      5                                           1er Piso
# 14    15                                           1er Piso
# 132  133                                          Logistica
# 26    27                                              Patio
# 100  101                                  Almacen Sopocachi
# 51    52                                        Planta Baja
# 101  102                                  Almacen Sopocachi
# 70    71                                        Planta Baja
# 41    42                                        Planta Baja
# 87    88                                       Supervisión
# 65    66                                        Planta Baja
# 16    17                                           1er Piso
# 134  135                                          Logistica
# 8      9                                           1er Piso
# 133  134                                          Logistica
# 130  131                                          Logistica
# 28    29                                              Patio
# 127  128                           Responsable de Logistica
# 35    36                                              Patio
# 112  113                                          Logistica
# 96    97  Jefatura de producción y Jefatura de Diseño y ...
# 88    89                                       Supervisión
# 102  103                                  Almacen Sopocachi
# 135  136                                          Logistica
# 113  114                                          Logistica
# 72    73                                        Planta Baja
# 103  104                                  Almacen Sopocachi
# 136  137                                          Logistica
# 66    67                                        Planta Baja
# 1      2                                           1er Piso
# 79    80                                        Planta Baja
# 42    43                                        Planta Baja
# 58    59                                        Planta Baja
# 57    58                                        Planta Baja
# 52    53                                        Planta Baja
# 7      8                                           1er Piso
# 12    13                                           1er Piso
# 30    31                                              Patio
# 20    21                                           1er Piso
# 36    37                                              Patio
# 17    18                                           1er Piso
# 48    49                                        Planta Baja
# 62    63                                        Planta Baja
# 37    38                                              Patio
# 110  111                                          Logistica
# 89    90  Jefatura de producción y Jefatura de Diseño y ...
# 120  121                           Responsable de Logistica
# 81    82                                       Supervisión
# 111  112                                          Logistica
# 82    83                                       Supervisión
# 121  122                           Responsable de Logistica
# 90    91  Jefatura de producción y Jefatura de Diseño y ...
# 85    86                                       Supervisión
# 24    25                                              Patio
# 5      6                                           1er Piso
# 39    40                                              Patio
# 129  130                                          Logistica
# 98    99                                  Almacen Sopocachi
# 115  116                                          Logistica
# 67    68                                        Planta Baja
# 137  138                                          Logistica
# 104  105                                  Almacen Sopocachi
# 15    16                                           1er Piso
# 34    35                                              Patio
# 21    22                                           1er Piso
# 6      7                                           1er Piso
# 75    76                                        Planta Baja
# 131  132                                          Logistica
# 25    26                                              Patio
# 99   100                                  Almacen Sopocachi
# 18    19                                           1er Piso
# 105  106                                  Almacen Sopocachi
# 86    87                                       Supervisión
# 106  107                                  Almacen Sopocachi
# 114  115                                          Logistica
# 139  140                                          Logistica
# 107  108                                  Almacen Sopocachi
# 140  141                                          Logistica
# 109  110                                  Almacen Sopocachi
# 117  118                                          Logistica
# 119  120                                          Logistica
# 108  109                                  Almacen Sopocachi
# 118  119                                          Logistica
# 141  142                                          Sopocachi
#
#      ACTIVIDAD / TAREA / LUGAR / EQUIPO / EVENTO  \
# 33                                      Parqueo
# 97                                     Almacenes
# 40   Oficina Jefatura Administracion Y  Finanzas
# 23                                Patio trasero
# 45               Area de Producción y Mensajeria
# 128                             Almacen El Alto
# 50          Area de Recepcion y Comercializacion
# 64                Oficina Desarrollo de Producto
# 55                                          BAÑO
# 69                             Oficina Logistica
# 60                                        Cocina
# 4                                        PASILLO
# 14                     OF SUB GERENCIA COMERCIAL
# 132                             Almacen El Alto
# 26                                Patio trasero
# 100                                    Almacenes
# 51          Area de Recepcion y Comercializacion
# 101                                    Almacenes
# 70                             Oficina Logistica
# 41   Oficina Jefatura Administracion Y  Finanzas
# 87                           Visitas  a talleres
# 65                Oficina Desarrollo de Producto
# 16                     OF SUB GERENCIA COMERCIAL
# 134                             Almacen El Alto
# 8                                        PASILLO
# 133                             Almacen El Alto
# 130                             Almacen El Alto
# 28                                Patio trasero
# 127                          Visitas  a talleres
# 35                                      Parqueo
# 112       Entrega, Recojo y Compra de Materiales
# 96                           Visitas  a talleres
# 88                           Visitas  a talleres
# 102                                    Almacenes
# 135                             Almacen El Alto
# 113       Entrega, Recojo y Compra de Materiales
# 72                             Oficina Logistica
# 103                                    Almacenes
# 136                             Almacen El Alto
# 66                Oficina Desarrollo de Producto
# 1                        OF SUB GERENCIA TECNICA
# 79                          Almacen de Marketing
# 42   Oficina Jefatura Administracion Y  Finanzas
# 58                                        Cocina
# 57                                          BAÑO
# 52          Area de Recepcion y Comercializacion
# 7                                        PASILLO
# 12                                   OF GERENCIA
# 30                                Patio trasero
# 20                             SALA DE REUNIONES
# 36                                      Parqueo
# 17                     OF SUB GERENCIA COMERCIAL
# 48               Area de Producción y Mensajeria
# 62      Closet (Deposito de Material de Oficina)
# 37                                      Parqueo
# 110       Entrega, Recojo y Compra de Materiales
# 89                           Visitas  a talleres
# 120                          Visitas  a talleres
# 81                           Visitas  a talleres
# 111       Entrega, Recojo y Compra de Materiales
# 82                           Visitas  a talleres
# 121                          Visitas  a talleres
# 90                           Visitas  a talleres
# 85                           Visitas  a talleres
# 24                                Patio trasero
# 5                                        PASILLO
# 39                                      Parqueo
# 129                             Almacen El Alto
# 98                                     Almacenes
# 115       Entrega, Recojo y Compra de Materiales
# 67                Oficina Desarrollo de Producto
# 137                             Almacen El Alto
# 104                                    Almacenes
# 15                     OF SUB GERENCIA COMERCIAL
# 34                                      Parqueo
# 21                             SALA DE REUNIONES
# 6                                        PASILLO
# 75                          Almacen de Marketing
# 131                             Almacen El Alto
# 25                                Patio trasero
# 99                                     Almacenes
# 18                                          BAÑO
# 105                                    Almacenes
# 86                           Visitas  a talleres
# 106                                    Almacenes
# 114       Entrega, Recojo y Compra de Materiales
# 139                             Almacen El Alto
# 107                                    Almacenes
# 140                             Almacen El Alto
# 109                                    Almacenes
# 117       Entrega, Recojo y Compra de Materiales
# 119       Entrega, Recojo y Compra de Materiales
# 108                                    Almacenes
# 118       Entrega, Recojo y Compra de Materiales
# 141                                         BAÑO
#
#              CONDICIÓN DE EVALUACIÓN  \
# 33                  Normal/Rutinaria
# 97                  Normal/Rutinaria
# 40                  Normal/Rutinaria
# 23                  Normal/Rutinaria
# 45                  Normal/Rutinaria
# 128                 Normal/Rutinaria
# 50                  Normal/Rutinaria
# 64                  Normal/Rutinaria
# 55                  Normal/Rutinaria
# 69                  Normal/Rutinaria
# 60                  Normal/Rutinaria
# 4                   Normal/Rutinaria
# 14                  Normal/Rutinaria
# 132                 Normal/Rutinaria
# 26                  Normal/Rutinaria
# 100                 Normal/Rutinaria
# 51                  Normal/Rutinaria
# 101                 Normal/Rutinaria
# 70                  Normal/Rutinaria
# 41                  Normal/Rutinaria
# 87                  Normal/Rutinaria
# 65                  Normal/Rutinaria
# 16                  Normal/Rutinaria
# 134  Anormal/Emergencia/No rutinaria
# 8                   Normal/Rutinaria
# 133                 Normal/Rutinaria
# 130                 Normal/Rutinaria
# 28   Anormal/Emergencia/No rutinaria
# 127                 Normal/Rutinaria
# 35                  Normal/Rutinaria
# 112                 Normal/Rutinaria
# 96                  Normal/Rutinaria
# 88                  Normal/Rutinaria
# 102                 Normal/Rutinaria
# 135                 Normal/Rutinaria
# 113  Anormal/Emergencia/No rutinaria
# 72   Anormal/Emergencia/No rutinaria
# 103  Anormal/Emergencia/No rutinaria
# 136  Anormal/Emergencia/No rutinaria
# 66   Anormal/Emergencia/No rutinaria
# 1    Anormal/Emergencia/No rutinaria
# 79   Anormal/Emergencia/No rutinaria
# 42   Anormal/Emergencia/No rutinaria
# 58   Anormal/Emergencia/No rutinaria
# 57   Anormal/Emergencia/No rutinaria
# 52   Anormal/Emergencia/No rutinaria
# 7    Anormal/Emergencia/No rutinaria
# 12   Anormal/Emergencia/No rutinaria
# 30   Anormal/Emergencia/No rutinaria
# 20   Anormal/Emergencia/No rutinaria
# 36   Anormal/Emergencia/No rutinaria
# 17   Anormal/Emergencia/No rutinaria
# 48   Anormal/Emergencia/No rutinaria
# 62   Anormal/Emergencia/No rutinaria
# 37                  Normal/Rutinaria
# 110                 Normal/Rutinaria
# 89                  Normal/Rutinaria
# 120                 Normal/Rutinaria
# 81                  Normal/Rutinaria
# 111                 Normal/Rutinaria
# 82                  Normal/Rutinaria
# 121                 Normal/Rutinaria
# 90                  Normal/Rutinaria
# 85                  Normal/Rutinaria
# 24                  Normal/Rutinaria
# 5                   Normal/Rutinaria
# 39                  Normal/Rutinaria
# 129                 Normal/Rutinaria
# 98                  Normal/Rutinaria
# 115                 Normal/Rutinaria
# 67                  Normal/Rutinaria
# 137                 Normal/Rutinaria
# 104                 Normal/Rutinaria
# 15                  Normal/Rutinaria
# 34   Anormal/Emergencia/No rutinaria
# 21   Anormal/Emergencia/No rutinaria
# 6    Anormal/Emergencia/No rutinaria
# 75   Anormal/Emergencia/No rutinaria
# 131  Anormal/Emergencia/No rutinaria
# 25   Anormal/Emergencia/No rutinaria
# 99   Anormal/Emergencia/No rutinaria
# 18                  Normal/Rutinaria
# 105                 Normal/Rutinaria
# 86                  Normal/Rutinaria
# 106  Anormal/Emergencia/No rutinaria
# 114  Anormal/Emergencia/No rutinaria
# 139                 Normal/Rutinaria
# 107                 Normal/Rutinaria
# 140                 Normal/Rutinaria
# 109                 Normal/Rutinaria
# 117  Anormal/Emergencia/No rutinaria
# 119                 Normal/Rutinaria
# 108                 Normal/Rutinaria
# 118                 Normal/Rutinaria
# 141                 Normal/Rutinaria
#
#     PELIGRO_x000D_\n_x000D_\n(Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001)  \
# 33           A1.      Caída de personas al mismo nivel
# 97           A1.      Caída de personas al mismo nivel
# 40           A1.      Caída de personas al mismo nivel
# 23           A1.      Caída de personas al mismo nivel
# 45           A1.      Caída de personas al mismo nivel
# 128          A1.      Caída de personas al mismo nivel
# 50           A1.      Caída de personas al mismo nivel
# 64           A1.      Caída de personas al mismo nivel
# 55           A1.      Caída de personas al mismo nivel
# 69           A1.      Caída de personas al mismo nivel
# 60           A1.      Caída de personas al mismo nivel
# 4            A1.      Caída de personas al mismo nivel
# 14           A1.      Caída de personas al mismo nivel
# 132  A10.   Cortes, golpes, penetraciones, excoriac...
# 26   A10.   Cortes, golpes, penetraciones, excoriac...
# 100  A10.   Cortes, golpes, penetraciones, excoriac...
# 51   A11.   Caída de objetos menores (menos de 5 kg...
# 101  A11.   Caída de objetos menores (menos de 5 kg...
# 70   A11.   Caída de objetos menores (menos de 5 kg...
# 41   A11.   Caída de objetos menores (menos de 5 kg...
# 87   A11.   Caída de objetos menores (menos de 5 kg...
# 65   A11.   Caída de objetos menores (menos de 5 kg...
# 16   A11.   Caída de objetos menores (menos de 5 kg...
# 134  A11.   Caída de objetos menores (menos de 5 kg...
# 8    A11.   Caída de objetos menores (menos de 5 kg...
# 133  A11.   Caída de objetos menores (menos de 5 kg...
# 130  A11.   Caída de objetos menores (menos de 5 kg...
# 28   A12.   Aplastamiento/Ahogamiento (entre objeto...
# 127  A13.   Golpes por objetos/equipos móviles o at...
# 35   A13.   Golpes por objetos/equipos móviles o at...
# 112  A13.   Golpes por objetos/equipos móviles o at...
# 96   A13.   Golpes por objetos/equipos móviles o at...
# 88   A13.   Golpes por objetos/equipos móviles o at...
# 102  A14.   Golpes por objetos inmóviles o partes s...
# 135  A14.   Golpes por objetos inmóviles o partes s...
# 113                                   A15.   Incendios
# 72                                    A15.   Incendios
# 103                                   A15.   Incendios
# 136                                   A15.   Incendios
# 66                                    A15.   Incendios
# 1                                     A15.   Incendios
# 79                                    A15.   Incendios
# 42                                    A15.   Incendios
# 58                                    A15.   Incendios
# 57                                    A15.   Incendios
# 52                                    A15.   Incendios
# 7                                     A15.   Incendios
# 12                                    A15.   Incendios
# 30                                    A15.   Incendios
# 20                                    A15.   Incendios
# 36                                    A15.   Incendios
# 17                                    A15.   Incendios
# 48                                    A15.   Incendios
# 62                                    A15.   Incendios
# 37           A17.   Choques de vehículos en movimiento
# 110          A17.   Choques de vehículos en movimiento
# 89           A17.   Choques de vehículos en movimiento
# 120          A17.   Choques de vehículos en movimiento
# 81           A17.   Choques de vehículos en movimiento
# 111             A18.   Vuelcos vehiculares o de equipo
# 82              A18.   Vuelcos vehiculares o de equipo
# 121             A18.   Vuelcos vehiculares o de equipo
# 90              A18.   Vuelcos vehiculares o de equipo
# 85                          A19.   Exposición a ruido
# 24   A2.      Caídas menores a distinto nivel (entr...
# 5    A2.      Caídas menores a distinto nivel (entr...
# 39   A2.      Caídas menores a distinto nivel (entr...
# 129  A2.      Caídas menores a distinto nivel (entr...
# 98   A2.      Caídas menores a distinto nivel (entr...
# 115  A2.      Caídas menores a distinto nivel (entr...
# 67          A21.   Exposición a inadecuada iluminación
# 137         A21.   Exposición a inadecuada iluminación
# 104         A21.   Exposición a inadecuada iluminación
# 15   A3.      Caídas mayores a distinto nivel (mayo...
# 34    A4.      Contactos eléctricos (Choque eléctrico)
# 21    A4.      Contactos eléctricos (Choque eléctrico)
# 6     A4.      Contactos eléctricos (Choque eléctrico)
# 75    A4.      Contactos eléctricos (Choque eléctrico)
# 131   A4.      Contactos eléctricos (Choque eléctrico)
# 25    A4.      Contactos eléctricos (Choque eléctrico)
# 99    A4.      Contactos eléctricos (Choque eléctrico)
# 18                    A8.      Atrapamientos mecánicos
# 105  B1.      Contacto o ingestión de sólidos/líqui...
# 86               B2.      Exposición a polvos o fibras
# 106  B4.      Derrames o fugas mayores de sustancia...
# 114  B4.      Derrames o fugas mayores de sustancia...
# 139         C1.      Ejecución de posturas inadecuadas
# 107         C1.      Ejecución de posturas inadecuadas
# 140       C3.      Ejecución de sobre esfuerzo físicos
# 109       C3.      Ejecución de sobre esfuerzo físicos
# 117              D6.     Convulsión social o atentados
# 119                      D7.     Desvío Comportamental
# 108                         D8.     Otros (describir*)
# 118                         D8.     Otros (describir*)
# 141                         D8.     Otros (describir*)
#
#     CONSECUENCIAS_x000D_\nmas probables_x000D_\n_x000D_\n(Lesiones o daños mas probables)  \
# 33    Traumatismos, heridas, Golpes, contusiones, e...
# 97    Traumatismos, heridas, Golpes, contusiones, e...
# 40    Traumatismos, heridas, Golpes, contusiones, e...
# 23    Traumatismos, heridas, Golpes, contusiones, e...
# 45    Traumatismos, heridas, Golpes, contusiones, e...
# 128   Traumatismos, heridas, Golpes, contusiones, e...
# 50    Traumatismos, heridas, Golpes, contusiones, e...
# 64    Traumatismos, heridas, Golpes, contusiones, e...
# 55    Traumatismos, heridas, Golpes, contusiones, e...
# 69    Traumatismos, heridas, Golpes, contusiones, e...
# 60                                Heridas, contusiones
# 4     Traumatismos, heridas, Golpes, contusiones, e...
# 14    Traumatismos, heridas, Golpes, contusiones, e...
# 132                               Heridas, contusiones
# 26                                Heridas, contusiones
# 100                               Heridas, contusiones
# 51                     Golpes, contusiones y fracturas
# 101                    Golpes, contusiones y fracturas
# 70                     Golpes, contusiones y fracturas
# 41                     Golpes, contusiones y fracturas
# 87                     Golpes, contusiones y fracturas
# 65                     Golpes, contusiones y fracturas
# 16                     Golpes, contusiones y fracturas
# 134     Fracturas, hemorragia interna, asfixia, muerte
# 8                      Golpes, contusiones y fracturas
# 133                    Golpes, contusiones y fracturas
# 130                              Golpes, contusiones,
# 28                       Fracturas, hemorragia interna
# 127                                 Fracturas, Heridas
# 35                                  Fracturas, Heridas
# 112     Fracturas, Heridas, hemorragia interna, muerte
# 96                                  Fracturas, Heridas
# 88                                  Fracturas, Heridas
# 102                       Golpes, contusiones, heridas
# 135                       Golpes, contusiones, heridas
# 113  Daños a instalaciones y/o equipos, quemaduras,...
# 72   Daños a instalaciones y/o equipos, quemaduras,...
# 103              Quemaduras de 1er, 2do y Tercer Grado
# 136  Daños a instalaciones y/o equipos, quemaduras,...
# 66   Daños a instalaciones y/o equipos, quemaduras,...
# 1    Daños a instalaciones y/o equipos, quemaduras,...
# 79   Daños a instalaciones y/o equipos, quemaduras,...
# 42   Daños a instalaciones y/o equipos, quemaduras,...
# 58   Daños a instalaciones y/o equipos, quemaduras,...
# 57   Daños a instalaciones y/o equipos, quemaduras,...
# 52   Daños a instalaciones y/o equipos, quemaduras,...
# 7    Daños a instalaciones y/o equipos, quemaduras,...
# 12   Daños a instalaciones y/o equipos, quemaduras,...
# 30   Daños a instalaciones y/o equipos, quemaduras,...
# 20       Daños a instalaciones y/o equipos, quemaduras
# 36   Daños a instalaciones y/o equipos, quemaduras,...
# 17   Daños a instalaciones y/o equipos, quemaduras,...
# 48   Daños a instalaciones y/o equipos, quemaduras,...
# 62   Daños a instalaciones y/o equipos, quemaduras,...
# 37                                  Fracturas, Heridas
# 110                         Fracturas, heridas, muerte
# 89                          Fracturas, heridas, muerte
# 120                         Fracturas, heridas, muerte
# 81                          Fracturas, heridas, muerte
# 111                         Fracturas, heridas, muerte
# 82                          Fracturas, heridas, muerte
# 121                         Fracturas, heridas, muerte
# 90                          Fracturas, heridas, muerte
# 85                                    Fatiga auditiva
# 24          Traumatismos, heridas, fracturas múltiples
# 5           Traumatismos, heridas, fracturas múltiples
# 39          Traumatismos, heridas, fracturas múltiples
# 129         Traumatismos, heridas, fracturas múltiples
# 98          Traumatismos, heridas, fracturas múltiples
# 115         Traumatismos, heridas, fracturas múltiples
# 67   Disminución en agudeza visual, fatiga visual, ...
# 137  Disminución en agudeza visual, fatiga visual, ...
# 104  Disminución en agudeza visual, fatiga visual, ...
# 15   Fracturas múltiples, Hemorragias internas, muerte
# 34   Quemaduras internas, externas, arritmia y paro...
# 21   Quemaduras internas, externas, arritmia y paro...
# 6    Quemaduras internas, externas, arritmia y paro...
# 75   Quemaduras internas, externas, arritmia y paro...
# 131  Quemaduras internas, externas, arritmia y paro...
# 25   Quemaduras internas, externas, arritmia y paro...
# 99   Quemaduras internas, externas, arritmia y paro...
# 18                    Heridas, fracturas, mutilaciones
# 105        Dermatitis, intoxicaciones o envenenamiento
# 86   Problemas pulmonares, irritaciones pulmonares,...
# 106  Daños a instalaciones y/o equipos Dermatitis, ...
# 114  Daños a instalaciones y/o equipos Dermatitis, ...
# 139   Desordenes musculo-esqueléticos, fatiga muscular
# 107   Desordenes musculo-esqueléticos, fatiga muscular
# 140        Desordenes musculo-esqueléticos, lumbalgias
# 109        Desordenes musculo-esqueléticos, lumbalgias
# 117                 Daños psicológicos, fatiga, estrés
# 119  Daños psicológicos, fatiga, estrés, irritabilidad
# 108   Malestar, fatiga, extravío de objetos personales
# 118           Malestar, extravío de objetos personales
# 141  Daños psicológicos, fatiga, estrés, irritabili...
#
#     DESVIO O CAUSA QUE ORIGINA EL PELIGRO_x000D_\n¿Por qué se genera el peligro?_x000D_\n_x000D_\nCausas/Devío: (Condiciones inseguras / Factores inseguros del Trabajo / Deficiencias de seguridad/ Actos Inseguros que generan el peligro)_x000D_\n_x000D_\nElementos: (Energías, equipos, maquinarias, sustancias, etc.)  \
# 33         Existencia de desniveles, exceso de maleza,
# 97     Poco espacio para circular; Material en el Piso
# 40   Superficie de área de trabajo en mal estado (A...
# 23   Existencia de desniveles, falta de limpieza, m...
# 45   Superficie de área de trabajo en mal estado (A...
# 128  Poco espacio para circular (1er piso delantero...
# 50   Superficie de área de trabajo en mal estado (A...
# 64   Alfombra desgastada, piso en mal estado ; jugu...
# 55                              Piso de ingreso dañado
# 69   Superficie de área de trabajo en mal estado (A...
# 60   Tablones en mal estado que genera riesgo de ca...
# 4    Superficie de área de trabajo en mal estado (A...
# 14   Superficie de área de trabajo en mal estado (A...
# 132       Cajas y Rejas sobresalidas; poca iluminacion
# 26   Corte por calaminas partes salientes y estruct...
# 100       Cajas y Rejas sobresalidas; poca iluminacion
# 51   Documentacion de Archivo a altura mayor a 2 mt...
# 101                          Cajones apilados a altura
# 70   Documentación a altura mayor a 2 mt en estante...
# 41   Documentacion Contable a altura mayor a 2 mt e...
# 87               Falta de orden y limpieza en talleres
# 65   Documentacion; juguetes, Materiales; cajas a a...
# 16                          Luminarias sin proteccion
# 134  Cajas llenas; cajas Vacias; Tablones Grandes y...
# 8                           Luminarias sin proteccion
# 133  Cajones apilados a altura; Luminarias sin prot...
# 130  Cajas apiladas en el primer piso que se encuen...
# 28   Escalera alojada en una posición alta y estant...
# 127  Traslado a talleres dentro de la cuidad sin ve...
# 35            No existe areas de circulacion peatonal
# 112               Actividad realizada en vias publicas
# 96   Traslado a talleres dentro de la cuidad sin ve...
# 88   Traslado a talleres dentro de la cuidad sin ve...
# 102             Disposición de Materiales mal ubicados
# 135  Disposición de Materiales mal ubicados; Cajas ...
# 113               Transporte de Sustancias Inflamables
# 72   Conexiones electricas mal ubicadas e inadecuad...
# 103                  Material Combustible e Inflamable
# 136                  Material Combustible e Inflamable
# 66   Conexiones electricas mal ubicadas e inadecuad...
# 1    Incendio por descargas eléctricas, cortos circ...
# 79   Conexiones electricas mal ubicadas e inadecuad...
# 42   Conexiones electricas mal ubicadas e inadecuad...
# 58   Conexiones electricas mal ubicadas e inadecuad...
# 57    Conexiones electricas mal ubicadas e inadecuadas
# 52   Conexiones electricas mal ubicadas e inadecuad...
# ...
# 66                                                 4.0
# 1                                                  4.0
# 79                                                 4.0
# 42                                                 4.0
# 58                                                 4.0
# 57                                                 4.0
# 52                                                 4.0
# 7                                                  4.0
# 12                                                 4.0
# 30                                                 4.0
# 20                                                 3.0
# 36                                                 4.0
# 17                                                 4.0
# 48                                                 4.0
# 62                                                 4.0
# 37                                                 3.0
# 110                                                3.0
# 89                                                 4.0
# 120                                                4.0
# 81                                                 4.0
# 111                                                3.0
# 82                                                 4.0
# 121                                                4.0
# 90                                                 4.0
# 85                                                 3.0
# 24                                                 2.0
# 5                                                  3.0
# 39                                                 2.0
# 129                                                2.0
# 98                                                 2.0
# 115                                                3.0
# 67                                                 2.0
# 137                                                2.0
# 104                                                2.0
# 15                                                 3.0
# 34                                                 3.0
# 21                                                 3.0
# 6                                                  3.0
# 75                                                 3.0
# 131                                                3.0
# 25                                                 3.0
# 99                                                 3.0
# 18                                                 3.0
# 105                                                3.0
# 86                                                 3.0
# 106                                                3.0
# 114                                                3.0
# 139                                                1.0
# 107                                                2.0
# 140                                                2.0
# 109                                                2.0
# 117                                                3.0
# 119                                                3.0
# 108                                                2.0
# 118                                                1.0
# 141                                                1.0
#
#      INPE.1  IFDE.1  ICO.1   ∑.1   Prob..2  Prob..3 NUEVO NIVEL DEL RIESGO  \
# 33      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 97      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 40      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 23      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 45      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 128     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 50      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 64      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 55      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 69      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 60      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 4       1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 14      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 132     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 26      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 100     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 51      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 101     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 70      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 41      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 87      1.0     4.0    6.0  11.0     Media      3.0                   Bajo
# 65      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 16      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 134     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 8       1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 133     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 130     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 28      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 127     1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 35      1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 112     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 96      1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 88      1.0     4.0    1.0   6.0  Muy Baja      1.0                   Bajo
# 102     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 135     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 113     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 72      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 103     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 136     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 66      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 1       1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 79      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 42      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 58      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 57      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 52      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 7       1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 12      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 30      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 20      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 36      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 17      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 48      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 62      1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 37      1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 110     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 89      1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 120     1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 81      1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 111     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 82      1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 121     1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 90      1.0     3.0    1.0   5.0  Muy Baja      1.0                   Bajo
# 85      1.0     3.0    6.0  10.0      Baja      2.0                   Bajo
# 24      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 5       1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 39      1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 129     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 98      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 115     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 67      1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 137     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 104     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 15      1.0     1.0    6.0   8.0      Baja      2.0                   Bajo
# 34      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 21      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 6       1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 75      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 131     1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 25      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 99      1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 18      1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 105     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 86      1.0     3.0    6.0  10.0      Baja      2.0                   Bajo
# 106     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 114     1.0     2.0    1.0   4.0  Muy Baja      1.0                   Bajo
# 139     1.0     5.0    1.0   7.0      Baja      2.0                Trivial
# 107     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 140     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 109     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 117     1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 119     1.0     2.0    6.0   9.0      Baja      2.0                   Bajo
# 108     1.0     5.0    1.0   7.0      Baja      2.0                   Bajo
# 118     1.0     5.0    6.0  12.0     Media      3.0                   Bajo
# 141     1.0     5.0    1.0   7.0      Baja      2.0                Trivial
#
#     ACEPTABLE / NO ACEPTABLE.1
# 33                   Aceptable
# 97                   Aceptable
# 40                   Aceptable
# 23                   Aceptable
# 45                   Aceptable
# 128                  Aceptable
# 50                   Aceptable
# 64                   Aceptable
# 55                   Aceptable
# 69                   Aceptable
# 60                   Aceptable
# 4                    Aceptable
# 14                   Aceptable
# 132                  Aceptable
# 26                   Aceptable
# 100                  Aceptable
# 51                   Aceptable
# 101                  Aceptable
# 70                   Aceptable
# 41                   Aceptable
# 87                   Aceptable
# 65                   Aceptable
# 16                   Aceptable
# 134                  Aceptable
# 8                    Aceptable
# 133                  Aceptable
# 130                  Aceptable
# 28                   Aceptable
# 127                  Aceptable
# 35                   Aceptable
# 112                  Aceptable
# 96                   Aceptable
# 88                   Aceptable
# 102                  Aceptable
# 135                  Aceptable
# 113                  Aceptable
# 72                   Aceptable
# 103                  Aceptable
# 136                  Aceptable
# 66                   Aceptable
# 1                    Aceptable
# 79                   Aceptable
# 42                   Aceptable
# 58                   Aceptable
# 57                   Aceptable
# 52                   Aceptable
# 7                    Aceptable
# 12                   Aceptable
# 30                   Aceptable
# 20                   Aceptable
# 36                   Aceptable
# 17                   Aceptable
# 48                   Aceptable
# 62                   Aceptable
# 37                   Aceptable
# 110                  Aceptable
# 89                   Aceptable
# 120                  Aceptable
# 81                   Aceptable
# 111                  Aceptable
# 82                   Aceptable
# 121                  Aceptable
# 90                   Aceptable
# 85                   Aceptable
# 24                   Aceptable
# 5                    Aceptable
# 39                   Aceptable
# 129                  Aceptable
# 98                   Aceptable
# 115                  Aceptable
# 67                   Aceptable
# 137                  Aceptable
# 104                  Aceptable
# 15                   Aceptable
# 34                   Aceptable
# 21                   Aceptable
# 6                    Aceptable
# 75                   Aceptable
# 131                  Aceptable
# 25                   Aceptable
# 99                   Aceptable
# 18                   Aceptable
# 105                  Aceptable
# 86                   Aceptable
# 106                  Aceptable
# 114                  Aceptable
# 139                  Aceptable
# 107                  Aceptable
# 140                  Aceptable
# 109                  Aceptable
# 117                  Aceptable
# 119                  Aceptable
# 108                  Aceptable
# 118                  Aceptable
# 141                  Aceptable

# %%
# Read the Excel file
file_path = 'PG_example.xlsx'
pg = pd.read_excel(file_path)
# Drop rows with NaN values
pg = df.dropna()

pg.head()
# Out:
#      # # PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN  \
# 0    1                    5,15, 41, 46, 51, 70
# 11  12                                      40
# 19  20                                       7
# 29  30                                      19
# 34  35                   9, 17, 42, 52, 66, 71
#
#                                              OBJETIVO  \
# 0   Prevenir traumatismos, heridas, Golpes, contus...
# 11  Prevenir traumatismos, heridas, Golpes, contus...
# 19  Prevenir lesiones ocasionadas por contactos el...
# 29  Prevenir lesiones ocasionadas por atrapamiento...
# 34           Prevenir golpes, contusiones y fracturas
#
#                                   PELIGRO RELACIONADO  \
# 0            A1. Caída de personas al mismo nivel\n\n
# 11  A2. Caídas menores a distinto nivel (entre 0,3...
# 19  A4. Contactos eléctricos (Choque eléctrico)\nA...
# 29                        A8. Atrapamientos mecánicos
# 34  A11. Caída de objetos menores (menos de 5 kg) ...
#
#                               META  \
# 0   100 % de Acividades Ejecutadas
# 11  100 % de Acividades Ejecutadas
# 19  100 % de Acividades Ejecutadas
# 29  100 % de Acividades Ejecutadas
# 34  100 % de Acividades Ejecutadas
#
#                                             ACTIVIDAD RESPONSABLE EJECUCIÓN  \
# 0   Mejorar las condiciones de las superficies de ...       Jenny Chuquimia
# 11  Realizar Matenimiento de la baranda de gradas ...       Jenny Chuquimia
# 19  Colocar candado de proteccion al tablero eléct...       Jenny Chuquimia
# 29  Cambiar la posición del ventilador a una mas a...     Cecilia Guachalla
# 34  Instalar protección contra caida necesaria a l...       Jenny Chuquimia
#
#    RECURSOS\n(Bs) PLAZOS (Dias) RESPONSABLE SEGUIMIENTO  \
# 0             500         41390        Mirko Taquichiri
# 11             30         41425         Ingrid Terrazas
# 19             50         41432        Mirko Taquichiri
# 29            150         41445        Mirko Taquichiri
# 34           3400         41425        Mirko Taquichiri
#
#    AVANCE DE  SEGUIMIENTO %
# 0                       100
# 11                      100
# 19                       13
# 29                       18
# 34                      100

# %%
iper = pd.DataFrame(columns=['#', 'SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO',
       'ACTIVIDAD / TAREA / LUGAR / EQUIPO / EVENTO',
       'CONDICIÓN DE EVALUACIÓN',
       'PELIGRO_x000D_\n_x000D_\n(Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001)',
       'CONSECUENCIAS_x000D_\nmas probables_x000D_\n_x000D_\n(Lesiones o daños mas probables)',
       'DESVIO O CAUSA QUE ORIGINA EL PELIGRO_x000D_\n¿Por qué se genera el peligro?_x000D_\n_x000D_\nCausas/Devío: (Condiciones inseguras / Factores inseguros del Trabajo / Deficiencias de seguridad/ Actos Inseguros que generan el peligro)_x000D_\n_x000D_\nElementos: (Energías, equipos, maquinarias, sustancias, etc.)',
       'DETERMINACIÓN DE LOS CONTROLES O PROTECCIÓNES EXISTENTES_x000D_\n_x000D_\n(Determine aquellos controles preventivos o de protección actualmente existentes)',
       'SEVERIDAD_x000D_\n_x000D_\nDEL DAÑO',
       'SEVERIDAD_x000D_\n_x000D_\nDEL DAÑO.1', 'INPE', 'IFDE', 'ICO',
       '∑', 'Prob.', 'Prob..1', 'NIVEL DEL RIESGO',
       'ACEPTABLE / NO ACEPTABLE', 'ES REQUISITO LEGAL? CUAL',
       'MEDIDAS ADICIONALES DE CONTROL O PROTECCIÓN  PROPUESTAS_x000D_\n_x000D_\n(Debe atacar las CAUSAS identificadas)_x000D_\n_x000D_\n1. Eliminacion: _x000D_\n2. Sustitucion: _x000D_\n3.Controles Ingenieria/Protección colectiva:_x000D_\n4. Señalización/Controles administrativos: _x000D_\n5. EPP:',
       'SEVERIDAD RESIDUAL _x000D_\nDEL DAÑO_x000D_\n_x000D_\n(analizar si hay disminución)',
       'SEVERIDAD RESIDUAL _x000D_\nDEL DAÑO_x000D_\n_x000D_\n(analizar si hay disminución).1',
       'INPE.1', 'IFDE.1', 'ICO.1', '∑.1', 'Prob..2', 'Prob..3',
       'NUEVO NIVEL DEL RIESGO', 'ACEPTABLE / NO ACEPTABLE.1'])

iper.head()
# Out:
# Empty DataFrame
# Columns: [#, SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO, ACTIVIDAD / TAREA / LUGAR / EQUIPO / EVENTO, CONDICIÓN DE EVALUACIÓN, PELIGRO_x000D_
# _x000D_
# (Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001), CONSECUENCIAS_x000D_
# mas probables_x000D_
# _x000D_
# (Lesiones o daños mas probables), DESVIO O CAUSA QUE ORIGINA EL PELIGRO_x000D_
# ¿Por qué se genera el peligro?_x000D_
# _x000D_
# Causas/Devío: (Condiciones inseguras / Factores inseguros del Trabajo / Deficiencias de seguridad/ Actos Inseguros que generan el peligro)_x000D_
# _x000D_
# Elementos: (Energías, equipos, maquinarias, sustancias, etc.), DETERMINACIÓN DE LOS CONTROLES O PROTECCIÓNES EXISTENTES_x000D_
# _x000D_
# (Determine aquellos controles preventivos o de protección actualmente existentes), SEVERIDAD_x000D_
# _x000D_
# DEL DAÑO, SEVERIDAD_x000D_
# _x000D_
# DEL DAÑO.1, INPE, IFDE, ICO, ∑, Prob., Prob..1, NIVEL DEL RIESGO, ACEPTABLE / NO ACEPTABLE, ES REQUISITO LEGAL? CUAL, MEDIDAS ADICIONALES DE CONTROL O PROTECCIÓN  PROPUESTAS_x000D_
# _x000D_
# (Debe atacar las CAUSAS identificadas)_x000D_
# _x000D_
# 1. Eliminacion: _x000D_
# 2. Sustitucion: _x000D_
# 3.Controles Ingenieria/Protección colectiva:_x000D_
# 4. Señalización/Controles administrativos: _x000D_
# 5. EPP:, SEVERIDAD RESIDUAL _x000D_
# DEL DAÑO_x000D_
# _x000D_
# (analizar si hay disminución), SEVERIDAD RESIDUAL _x000D_
# DEL DAÑO_x000D_
# _x000D_
# (analizar si hay disminución).1, INPE.1, IFDE.1, ICO.1, ∑.1, Prob..2, Prob..3, NUEVO NIVEL DEL RIESGO, ACEPTABLE / NO ACEPTABLE.1]
# Index: []

# %%
pg = pd.DataFrame(columns=['#', '# PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN', 'OBJETIVO',
       'PELIGRO RELACIONADO', 'META', 'ACTIVIDAD',
       'RESPONSABLE EJECUCIÓN', 'RECURSOS\n(Bs)', 'PLAZOS (Dias)',
       'RESPONSABLE SEGUIMIENTO', 'AVANCE DE  SEGUIMIENTO %'])

pg.head()
# Out:
# Empty DataFrame
# Columns: [#, # PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN, OBJETIVO, PELIGRO RELACIONADO, META, ACTIVIDAD, RESPONSABLE EJECUCIÓN, RECURSOS
# (Bs), PLAZOS (Dias), RESPONSABLE SEGUIMIENTO, AVANCE DE  SEGUIMIENTO %]
# Index: []

# %%
class gestion_program(pd.DataFrame):
    def __init__(self, IPER):
        peligros = IPER['PELIGRO_x000D_\n_x000D_\n(Evento Peligroso, categorias de Lista Maestra OST-SGI.SI.001)'].unique()
        indices = IPER['#'].unique()
        sectores = IPER['SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO'].unique()
        
        # Crear DataFrame con las columnas especificadas
        super().__init__(columns=['#', '# PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN', 'OBJETIVO',
                                 'PELIGRO RELACIONADO', 'META', 'ACTIVIDAD',
                                 'RESPONSABLE EJECUCIÓN', 'RECURSOS\n(Bs)', 'PLAZOS (Dias)',
                                 'RESPONSABLE SEGUIMIENTO', 'AVANCE DE  SEGUIMIENTO %'])
        
        # Generar filas por combinación de sector y peligro
        for peligro in peligros:
            for indice in indices:
                sector = IPER.loc[IPER['#'] == indice, 'SECTOR / AREA / UNIDAD / PROCESO O SUB-PROCESO'].values[0]
                objetivo = "Generar objetivo para todas las filas que compartan sector y peligro"
                actividad = "Generar con la API de OpenAI ChatGPT una actividad enfocada en resolver los peligros en ese sector, especificando los subsectores de cada índice involucrado."
                
                self.loc[len(self)] = [str(indice), ','.join(map(str, indices)), objetivo, peligro, "100 % de Actividades Ejecutadas",
                                       actividad, '', '', '', '', '0.00']

# %%
pg_1=gestion_program(df)

# %%
pg_1.head()
# Out:
#    #            # PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN  \
# 0  2  2,5,6,7,8,9,13,15,16,17,18,19,21,22,24,25,26,2...
# 1  5  2,5,6,7,8,9,13,15,16,17,18,19,21,22,24,25,26,2...
# 2  6  2,5,6,7,8,9,13,15,16,17,18,19,21,22,24,25,26,2...
# 3  7  2,5,6,7,8,9,13,15,16,17,18,19,21,22,24,25,26,2...
# 4  8  2,5,6,7,8,9,13,15,16,17,18,19,21,22,24,25,26,2...
#
#                                             OBJETIVO PELIGRO RELACIONADO  \
# 0  Generar objetivo para todas las filas que comp...    A15.   Incendios
# 1  Generar objetivo para todas las filas que comp...    A15.   Incendios
# 2  Generar objetivo para todas las filas que comp...    A15.   Incendios
# 3  Generar objetivo para todas las filas que comp...    A15.   Incendios
# 4  Generar objetivo para todas las filas que comp...    A15.   Incendios
#
#                               META  \
# 0  100 % de Actividades Ejecutadas
# 1  100 % de Actividades Ejecutadas
# 2  100 % de Actividades Ejecutadas
# 3  100 % de Actividades Ejecutadas
# 4  100 % de Actividades Ejecutadas
#
#                                            ACTIVIDAD RESPONSABLE EJECUCIÓN  \
# 0  Generar con la API de OpenAI ChatGPT una activ...
# 1  Generar con la API de OpenAI ChatGPT una activ...
# 2  Generar con la API de OpenAI ChatGPT una activ...
# 3  Generar con la API de OpenAI ChatGPT una activ...
# 4  Generar con la API de OpenAI ChatGPT una activ...
#
#   RECURSOS\n(Bs) PLAZOS (Dias) RESPONSABLE SEGUIMIENTO  \
# 0
# 1
# 2
# 3
# 4
#
#   AVANCE DE  SEGUIMIENTO %
# 0                     0.00
# 1                     0.00
# 2                     0.00
# 3                     0.00
# 4                     0.00

# %%
pg_1.info()
# Out:
# <class '__main__.gestion_program'>
# Int64Index: 2185 entries, 0 to 2184
# Data columns (total 11 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   #                                        2185 non-null   object
#  1   # PLANILLA IDENTIFICACIÓN  Y EVALUACIÓN  2185 non-null   object
#  2   OBJETIVO                                 2185 non-null   object
#  3   PELIGRO RELACIONADO                      2185 non-null   object
#  4   META                                     2185 non-null   object
#  5   ACTIVIDAD                                2185 non-null   object
#  6   RESPONSABLE EJECUCIÓN                    2185 non-null   object
#  7   RECURSOS
# (Bs)                            2185 non-null   object
#  8   PLAZOS (Dias)                            2185 non-null   object
#  9   RESPONSABLE SEGUIMIENTO                  2185 non-null   object
#  10  AVANCE DE  SEGUIMIENTO %                 2185 non-null   object
# dtypes: object(11)
# memory usage: 204.8+ KB
